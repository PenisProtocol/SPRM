# %%
# magic command to install packages

# %pip install numpy Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL
from PIL import Image
import numpy as np
import hashlib

# Create the image
W = 64
H = 64
C = 3

img = Image.new('L', (W, H), (0)) 

# load the source image
srcimg = Image.open('./sampleimage.jpg')
srcimg.convert('L')

# resize and put
srcimg = srcimg.resize((W, H))
img.paste(srcimg, (0, 0))
            

# Display the image
img.show()

# get the vector, get hash
img_array = np.array(img)
print(img_array.shape)

sha256 = hashlib.sha256(img_array.tobytes()).hexdigest()

print(sha256)

print("Data to be padded: ", img_array.tobytes().hex())

# set zero for (0,0,0) to (32, 64,0)  
masked = img_array.copy()
masked[0:32, 0:64] = 0


# Display the masked image
Image.fromarray(masked).show()

datahex = "..."
databin = bytes.fromhex(datahex)
# Out:
# <PIL.Image.Image image mode=L size=64x64>
# (64, 64)
# 1acdea8e75bc14075b0bcd041245244f2b126584a39c44b2718ebeda310e1c9e
# Data to be padded:  ...
# <PIL.Image.Image image mode=L size=64x64>

# %%
# show databin as L image
newimg = Image.new('L', (W, 32), (0))

newimg.putdata(databin)
newimg.show()
# Out:
# <PIL.Image.Image image mode=L size=64x32>
